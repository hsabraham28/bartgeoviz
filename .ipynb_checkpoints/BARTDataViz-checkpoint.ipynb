# %%
import pandas as pd
from IPython import display
stationlocs = pd.read_csv("BARTLocationPercentages.csv")
print(stationlocs)
# Out:
#     Station_Name  X_Percentage  Y_Percentage  Rain_Critical  \
# 0    A50_TCR_105        51.968        57.745              1
# 1        A10_TCR        41.631        46.257              1
# 2        R60_TCR        24.080        13.060              1
# 3    R50_TCR_105        26.500        15.830              1
# 4        R10_TCR        36.250        26.480              1
# ..           ...           ...           ...            ...
# 295  E10-TEMPMON        67.665        11.020              0
# 296  E39-TEMPMON        80.000        11.000              0
# 297   C55-TC-UPS        56.917        11.881              0
# 298   E10-TC-UPS        67.665        11.020              0
# 299   NOAA_ALERT        11.000         6.000              0
#
#            Asset_Location
# 0                Bay Fair
# 1            Lake Merritt
# 2                Richmond
# 3    El Cerrito Del Norte
# 4                   Ashby
# ..                    ...
# 295    Temperature Sensor
# 296    Temperature Sensor
# 297    Temperature Sensor
# 298    Temperature Sensor
# 299       Emergency Alert
#
# [300 rows x 5 columns]

# %%
display.Image("./BARTtracksmap.png")

# %%
x = stationlocs['Station_Name'].tolist()

# %%
x
# Out:
# ['A50_TCR_105',
#  'A10_TCR',
#  'R60_TCR',
#  'R50_TCR_105',
#  'R10_TCR',
#  'M90_TCR_116A',
#  'M90_TCR_114',
#  'M90_TCR_113',
#  'M90_TCR_112',
#  'M10_TCR',
#  'L30_TCR_108D',
#  'K30_TCR',
#  'C10_TCR',
#  'A20_TCR_108',
#  'A20_TCR_107',
#  'C60_TCR',
#  'C50_TCR_104',
#  'Y10_TCR_B',
#  'Y10_TCR_A',
#  'Y10_TCR_552',
#  'W40_TCR',
#  'W40_TCR_103A',
#  'W40_TCR_103',
#  'W40_TCR_102',
#  'W34_TCR',
#  'W30_TCR',
#  'W20_TCR_101',
#  'W10_TCR_111E',
#  'W10_TCR_110',
#  'S50_TCR',
#  'S44_TCH',
#  'S40_TCR',
#  'S28_TCH',
#  'S26_TCH',
#  'S24_TCH',
#  'S20_TCR',
#  'S12_TCR',
#  'S06_TCR',
#  'R40_TCR_105',
#  'R30_TCR_110A',
#  'R30_TCR_110',
#  'R20_TCR_105C',
#  'ORY_TCR_101',
#  'M50_TCR_101D',
#  'M40_TCR_106B',
#  'M30_TCR_102D',
#  'M20_TCR',
#  'M16_TCR',
#  'ODY_TCR_106',
#  'M94_TCR_MSC',
#  'M80_TCR_106',
#  'M80_TCR_105',
#  'M70_TCR_205',
#  'M60_TCR_101D',
#  'L20_TCR',
#  'L18_TCR',
#  'L16_TCR',
#  'L14_TCR',
#  'L10_TCR_102A',
#  'L06_TCR',
#  'C20_TCR',
#  'C88_TCR',
#  'C80_TCR',
#  'C76_TCR',
#  'C70_TCR_109',
#  'OCY_TCR',
#  'C54_TCR',
#  'C40_TCR',
#  'C30_TCR',
#  'K20_TCR_213E',
#  'K10_TCR_102B',
#  'K10_TCR_101B',
#  'K10_TCR_101',
#  'A40_TCR',
#  'A30_TCR_105A',
#  'A90_TCR',
#  'A80_TCR_101C',
#  'A80_TCR_101',
#  'A80_TCR_101B',
#  'HTT_TCR',
#  'OHY_TCR',
#  'A70_TCR',
#  'A60_TCR',
#  'A58_TCR',
#  'E30_TCR',
#  'E10_TCR',
#  'P-369',
#  'P-333',
#  'P-008',
#  'A-351',
#  'P-356',
#  'P-363',
#  'A-387',
#  'P-341',
#  'A-25',
#  'P-375',
#  'P-148',
#  'P-018',
#  'P-078',
#  'P-188',
#  'P-313',
#  'P-062',
#  'P-150',
#  'P-183',
#  'P-38',
#  'P-215B',
#  'P-174',
#  'B-231',
#  'P-216A',
#  'P-179',
#  'P-140',
#  'P-55',
#  'A-200',
#  'A-266',
#  'A-108',
#  'P-142',
#  'P-44',
#  'P-288',
#  'A-151',
#  'P-112',
#  'A-118_CL',
#  'P-48',
#  'A-99',
#  'B-8',
#  'A-55',
#  'A-274',
#  'P-236',
#  'A-96_CL',
#  'P-280',
#  'P-153',
#  'A-211',
#  'B-305',
#  'P-254',
#  'P-190',
#  'A-139',
#  'P-31_RL',
#  'A-861',
#  'A-811',
#  'A-868',
#  'P-44_2',
#  'P-2',
#  'P-251',
#  'P-788',
#  'P-651',
#  'P-304',
#  'P-438',
#  'P-729',
#  'A-796',
#  'P-809',
#  'P-234',
#  'P-154',
#  'P-634',
#  'P-835',
#  'P-377',
#  'P-900',
#  'P-532',
#  'P-73',
#  'A50-TEMPMON',
#  'A50-TC-UPS',
#  'A10-TEMPMON',
#  'A10-TC-UPS',
#  'R60-TEMPMON',
#  'R60-TC-UPS',
#  'R50-TEMPMON',
#  'R50-TC-UPS',
#  'R10-TEMPMON',
#  'R10-TC-UPS',
#  'M90-TEMPMON',
#  'M90-TC-UPS',
#  'M10-TEMPMON',
#  'M10-TC-UPS',
#  'L30-TEMPMON',
#  'L30-TC-UPS',
#  'K30-TEMPMON',
#  'K30-TC-UPS',
#  'C10-TEMPMON',
#  'C10-TC-UPS',
#  'A20-TEMPMON',
#  'A20-TC-UPS',
#  'C60-TEMPMON',
#  'C60-TC-UPS',
#  'C50-TEMPMON',
#  'C50-TC-UPS',
#  'Y10-TEMPMON',
#  'Y10-TC-UPS',
#  'W40-TEMPMON',
#  'W40-TC-UPS',
#  'W34-TEMPMON',
#  'W34-TC-UPS',
#  'W30-TEMPMON',
#  'W30-TC-UPS',
#  'W20-TEMPMON',
#  'W20-TC-UPS',
#  'W10-TEMPMON',
#  'W10-TC-UPS',
#  'S50-TEMPMON',
#  'S50-TC-UPS',
#  'S44-TEMPMON',
#  'S44-TC-UPS',
#  'S40-TEMPMON',
#  'S40-TC-UPS',
#  'S28-TEMPMON',
#  'S28-TC-UPS',
#  'S26-TEMPMON',
#  'S26-TC-UPS',
#  'S24-TEMPMON',
#  'S24-TC-UPS',
#  'S20-TEMPMON',
#  'S20-TC-UPS',
#  'S12-TEMPMON',
#  'S12-TC-UPS',
#  'S06-TEMPMON',
#  'S06-TC-UPS',
#  'R40-TEMPMON',
#  'R40-TC-UPS',
#  'R30-TEMPMON',
#  'R30-TC-UPS',
#  'R20-TEMPMON',
#  'R20-TC-UPS',
#  'ORY-TEMPMON',
#  'ORY-TC-UPS',
#  'M50-TEMPMON',
#  'M50-TC-UPS',
#  'M40-TEMPMON',
#  'M40-TC-UPS',
#  'M30-TEMPMON',
#  'M30-TC-UPS',
#  'M20-TEMPMON',
#  'M20-TC-UPS',
#  'M16-TEMPMON',
#  'M16-TC-UPS',
#  'ODY-TEMPMON',
#  'ODY-TC-UPS',
#  'M94-TEMPMON',
#  'M94-TC-UPS',
#  'M80-TEMPMON',
#  'M80-TC-UPS',
#  'M70-TEMPMON',
#  'M70-TC-UPS',
#  'M60-TEMPMON',
#  'M60-TC-UPS',
#  'L20-TEMPMON',
#  'L20-TC-UPS',
#  'L18-TEMPMON',
#  'L18-TC-UPS',
#  'L16-TEMPMON',
#  'L16-TC-UPS',
#  'L14-TEMPMON',
#  'L14-TC-UPS',
#  'L10-TEMPMON',
#  'L10-TC-UPS',
#  'L06-TEMPMON',
#  'L06-TC-UPS',
#  'C20-TEMPMON',
#  'C20-TC-UPS',
#  'C88-TEMPMON',
#  'C88-TC-UPS',
#  'C80-TEMPMON',
#  'C80-TC-UPS',
#  'C76-TEMPMON',
#  'C76-TC-UPS',
#  'C70-TEMPMON',
#  'C70-TC-UPS',
#  'OCY-TEMPMON',
#  'OCY-TC-UPS',
#  'C54-TEMPMON',
#  'C54-TC-UPS',
#  'C40-TEMPMON',
#  'C40-TC-UPS',
#  'C30-TEMPMON',
#  'C30-TC-UPS',
#  'K20-TEMPMON',
#  'K20-TC-UPS',
#  'K10-TEMPMON',
#  'K10-TC-UPS',
#  'A40-TEMPMON',
#  'A40-TC-UPS',
#  'A30-TEMPMON',
#  'A30-TC-UPS',
#  'A90-TEMPMON',
#  'A90-TC-UPS',
#  'A80-TEMPMON',
#  'A80-TC-UPS',
#  'HTT-TEMPMON',
#  'HTT-TC-UPS',
#  'OHY-TEMPMON',
#  'OHY-TC-UPS',
#  'A70-TEMPMON',
#  'A70-TC-UPS',
#  'A60-TEMPMON',
#  'A60-TC-UPS',
#  'A58-TEMPMON',
#  'A58-TC-UPS',
#  'E30-TEMPMON',
#  'E30-TC-UPS',
#  'E10-TEMPMON',
#  'E39-TEMPMON',
#  'C55-TC-UPS',
#  'E10-TC-UPS',
#  'NOAA_ALERT']

# %%
y = 'M10'

# %%
y
# Out:
# 'M10'

# %%
for i in x:
    if y in i:
        print(i)
# Out:
# M10_TCR
# M10-TEMPMON
# M10-TC-UPS

# %%
testlog = pd.read_csv("testocclog.csv")
print(testlog.columns)
# Out:
# Index(['Time', 'Ref', 'Log', 'BPD', 'Location'], dtype='object')

# %%
testlog = testlog.drop(columns=['BPD', 'Ref'])

# %%
print(testlog)
# Out:
#     Time                                                Log Location
# 0    622  DMZ1 issued Cat B W/O's for MW02 to set on and...      M60
# 1    640  DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60
# 2    656  DMZ1 issued Cat B W/O's for the M55XL to crank...      M55
# 3    658  T950 Inspection train in C80 TM1 dispatching t...      C80
# 4    700  Single Tracking established on the M2 Track be...      M17
# 5    703  DMZ1 cleared Cat B W/O's for the M55XL. Protec...      M55
# 6    732  T918 completed track inspection on the C2 Trac...      C20
# 7    735  T229 verified A78[A1/A2] cranked, clamped and ...      A78
# 8    745  T918 completed track inspection on the C1 Trac...      K10
# 9    753                      T221 R60-2 No ATO doors, 311.      R60
# 10   753  T507 issued road manual into M40-2 and verifie...      M40
# 11   753                      T221 R60-2 No ATO doors, 311.      R60
# 12   753  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10
# 13   756       C/K Line opened and staffed per SOFO.[Bucio]      C10
# 14   759                      T221 R50-2 No ATO doors, 311.      R50
# 15   801       M/W Line opened and staffed per SOFO[Bucio].      M10
# 16   802                      T221 R40-2 No ATO doors, 311.      R40
# 17   806  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30
# 18   809                       T221 R20- No ATO doors, 311.      R20
# 19   811                      T221 R10-2 No ATO doors, 311.      R10
# 20   815  OL05 issued Cat B W/O's for the M1 Track betwe...      M17
# 21   816  T221 late arrival to K30-2, forced meet with T...      K30
# 22   818  OL05 cleared Cat B W/O's for the M1 Track betw...      M17

# %%
stationarr = (stationlocs['Station_Name']).tolist()
sarr = []
for s in stationarr:
    s = s[0:3]
    sarr.append(s)

# %%
sarr
# Out:
# ['A50',
#  'A10',
#  'R60',
#  'R50',
#  'R10',
#  'M90',
#  'M90',
#  'M90',
#  'M90',
#  'M10',
#  'L30',
#  'K30',
#  'C10',
#  'A20',
#  'A20',
#  'C60',
#  'C50',
#  'Y10',
#  'Y10',
#  'Y10',
#  'W40',
#  'W40',
#  'W40',
#  'W40',
#  'W34',
#  'W30',
#  'W20',
#  'W10',
#  'W10',
#  'S50',
#  'S44',
#  'S40',
#  'S28',
#  'S26',
#  'S24',
#  'S20',
#  'S12',
#  'S06',
#  'R40',
#  'R30',
#  'R30',
#  'R20',
#  'ORY',
#  'M50',
#  'M40',
#  'M30',
#  'M20',
#  'M16',
#  'ODY',
#  'M94',
#  'M80',
#  'M80',
#  'M70',
#  'M60',
#  'L20',
#  'L18',
#  'L16',
#  'L14',
#  'L10',
#  'L06',
#  'C20',
#  'C88',
#  'C80',
#  'C76',
#  'C70',
#  'OCY',
#  'C54',
#  'C40',
#  'C30',
#  'K20',
#  'K10',
#  'K10',
#  'K10',
#  'A40',
#  'A30',
#  'A90',
#  'A80',
#  'A80',
#  'A80',
#  'HTT',
#  'OHY',
#  'A70',
#  'A60',
#  'A58',
#  'E30',
#  'E10',
#  'P-3',
#  'P-3',
#  'P-0',
#  'A-3',
#  'P-3',
#  'P-3',
#  'A-3',
#  'P-3',
#  'A-2',
#  'P-3',
#  'P-1',
#  'P-0',
#  'P-0',
#  'P-1',
#  'P-3',
#  'P-0',
#  'P-1',
#  'P-1',
#  'P-3',
#  'P-2',
#  'P-1',
#  'B-2',
#  'P-2',
#  'P-1',
#  'P-1',
#  'P-5',
#  'A-2',
#  'A-2',
#  'A-1',
#  'P-1',
#  'P-4',
#  'P-2',
#  'A-1',
#  'P-1',
#  'A-1',
#  'P-4',
#  'A-9',
#  'B-8',
#  'A-5',
#  'A-2',
#  'P-2',
#  'A-9',
#  'P-2',
#  'P-1',
#  'A-2',
#  'B-3',
#  'P-2',
#  'P-1',
#  'A-1',
#  'P-3',
#  'A-8',
#  'A-8',
#  'A-8',
#  'P-4',
#  'P-2',
#  'P-2',
#  'P-7',
#  'P-6',
#  'P-3',
#  'P-4',
#  'P-7',
#  'A-7',
#  'P-8',
#  'P-2',
#  'P-1',
#  'P-6',
#  'P-8',
#  'P-3',
#  'P-9',
#  'P-5',
#  'P-7',
#  'A50',
#  'A50',
#  'A10',
#  'A10',
#  'R60',
#  'R60',
#  'R50',
#  'R50',
#  'R10',
#  'R10',
#  'M90',
#  'M90',
#  'M10',
#  'M10',
#  'L30',
#  'L30',
#  'K30',
#  'K30',
#  'C10',
#  'C10',
#  'A20',
#  'A20',
#  'C60',
#  'C60',
#  'C50',
#  'C50',
#  'Y10',
#  'Y10',
#  'W40',
#  'W40',
#  'W34',
#  'W34',
#  'W30',
#  'W30',
#  'W20',
#  'W20',
#  'W10',
#  'W10',
#  'S50',
#  'S50',
#  'S44',
#  'S44',
#  'S40',
#  'S40',
#  'S28',
#  'S28',
#  'S26',
#  'S26',
#  'S24',
#  'S24',
#  'S20',
#  'S20',
#  'S12',
#  'S12',
#  'S06',
#  'S06',
#  'R40',
#  'R40',
#  'R30',
#  'R30',
#  'R20',
#  'R20',
#  'ORY',
#  'ORY',
#  'M50',
#  'M50',
#  'M40',
#  'M40',
#  'M30',
#  'M30',
#  'M20',
#  'M20',
#  'M16',
#  'M16',
#  'ODY',
#  'ODY',
#  'M94',
#  'M94',
#  'M80',
#  'M80',
#  'M70',
#  'M70',
#  'M60',
#  'M60',
#  'L20',
#  'L20',
#  'L18',
#  'L18',
#  'L16',
#  'L16',
#  'L14',
#  'L14',
#  'L10',
#  'L10',
#  'L06',
#  'L06',
#  'C20',
#  'C20',
#  'C88',
#  'C88',
#  'C80',
#  'C80',
#  'C76',
#  'C76',
#  'C70',
#  'C70',
#  'OCY',
#  'OCY',
#  'C54',
#  'C54',
#  'C40',
#  'C40',
#  'C30',
#  'C30',
#  'K20',
#  'K20',
#  'K10',
#  'K10',
#  'A40',
#  'A40',
#  'A30',
#  'A30',
#  'A90',
#  'A90',
#  'A80',
#  'A80',
#  'HTT',
#  'HTT',
#  'OHY',
#  'OHY',
#  'A70',
#  'A70',
#  'A60',
#  'A60',
#  'A58',
#  'A58',
#  'E30',
#  'E30',
#  'E10',
#  'E39',
#  'C55',
#  'E10',
#  'NOA']

# %%
stationlocs['Location'] = sarr

# %%
print(stationlocs)
# Out:
#     Station_Name  X_Percentage  Y_Percentage  Rain_Critical  \
# 0    A50_TCR_105        51.968        57.745              1
# 1        A10_TCR        41.631        46.257              1
# 2        R60_TCR        24.080        13.060              1
# 3    R50_TCR_105        26.500        15.830              1
# 4        R10_TCR        36.250        26.480              1
# ..           ...           ...           ...            ...
# 295  E10-TEMPMON        67.665        11.020              0
# 296  E39-TEMPMON        80.000        11.000              0
# 297   C55-TC-UPS        56.917        11.881              0
# 298   E10-TC-UPS        67.665        11.020              0
# 299   NOAA_ALERT        11.000         6.000              0
#
#            Asset_Location Location
# 0                Bay Fair      A50
# 1            Lake Merritt      A10
# 2                Richmond      R60
# 3    El Cerrito Del Norte      R50
# 4                   Ashby      R10
# ..                    ...      ...
# 295    Temperature Sensor      E10
# 296    Temperature Sensor      E39
# 297    Temperature Sensor      C55
# 298    Temperature Sensor      E10
# 299       Emergency Alert      NOA
#
# [300 rows x 6 columns]

# %%
justxandy = stationlocs.drop(columns=['Station_Name', 'Rain_Critical', 'Asset_Location'])

# %%
print(justxandy)
# Out:
#      X_Percentage  Y_Percentage Location
# 0          51.968        57.745      A50
# 1          41.631        46.257      A10
# 2          24.080        13.060      R60
# 3          26.500        15.830      R50
# 4          36.250        26.480      R10
# ..            ...           ...      ...
# 295        67.665        11.020      E10
# 296        80.000        11.000      E39
# 297        56.917        11.881      C55
# 298        67.665        11.020      E10
# 299        11.000         6.000      NOA
#
# [300 rows x 3 columns]

# %%
merged = testlog.merge(justxandy.set_index('Location'), on='Location')

# %%
merged
# Out:
#     level_0_x  index_x  Time  \
# 0           0        0   622
# 1           0        0   622
# 2           0        0   622
# 3           1        1   640
# 4           1        1   640
# 5           1        1   640
# 6           3        3   658
# 7           3        3   658
# 8           3        3   658
# 9           6        6   732
# 10          6        6   732
# 11          6        6   732
# 12          8        8   745
# 13          8        8   745
# 14          8        8   745
# 15          8        8   745
# 16          8        8   745
# 17          9        9   753
# 18          9        9   753
# 19          9        9   753
# 20         11       11   753
# 21         11       11   753
# 22         11       11   753
# 23         10       10   753
# 24         10       10   753
# 25         10       10   753
# 26         12       12   753
# 27         12       12   753
# 28         12       12   753
# 29         19       19   811
# 30         19       19   811
# 31         19       19   811
# 32         13       13   756
# 33         13       13   756
# 34         13       13   756
# 35         14       14   759
# 36         14       14   759
# 37         14       14   759
# 38         15       15   801
# 39         15       15   801
# 40         15       15   801
# 41         16       16   802
# 42         16       16   802
# 43         16       16   802
# 44         17       17   806
# 45         17       17   806
# 46         17       17   806
# 47         17       17   806
# 48         18       18   809
# 49         18       18   809
# 50         18       18   809
# 51         21       21   816
# 52         21       21   816
# 53         21       21   816
#
#                                                   Log Location  level_0_y  \
# 0   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60         53
# 1   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60        239
# 2   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60        240
# 3   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60         53
# 4   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60        239
# 5   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60        240
# 6   T950 Inspection train in C80 TM1 dispatching t...      C80         62
# 7   T950 Inspection train in C80 TM1 dispatching t...      C80        257
# 8   T950 Inspection train in C80 TM1 dispatching t...      C80        258
# 9   T918 completed track inspection on the C2 Trac...      C20         60
# 10  T918 completed track inspection on the C2 Trac...      C20        253
# 11  T918 completed track inspection on the C2 Trac...      C20        254
# 12  T918 completed track inspection on the C1 Trac...      K10         70
# 13  T918 completed track inspection on the C1 Trac...      K10         71
# 14  T918 completed track inspection on the C1 Trac...      K10         72
# 15  T918 completed track inspection on the C1 Trac...      K10        273
# 16  T918 completed track inspection on the C1 Trac...      K10        274
# 17                      T221 R60-2 No ATO doors, 311.      R60          2
# 18                      T221 R60-2 No ATO doors, 311.      R60        161
# 19                      T221 R60-2 No ATO doors, 311.      R60        162
# 20                      T221 R60-2 No ATO doors, 311.      R60          2
# 21                      T221 R60-2 No ATO doors, 311.      R60        161
# 22                      T221 R60-2 No ATO doors, 311.      R60        162
# 23  T507 issued road manual into M40-2 and verifie...      M40         44
# 24  T507 issued road manual into M40-2 and verifie...      M40        223
# 25  T507 issued road manual into M40-2 and verifie...      M40        224
# 26  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10          4
# 27  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10        165
# 28  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10        166
# 29                      T221 R10-2 No ATO doors, 311.      R10          4
# 30                      T221 R10-2 No ATO doors, 311.      R10        165
# 31                      T221 R10-2 No ATO doors, 311.      R10        166
# 32       C/K Line opened and staffed per SOFO.[Bucio]      C10         12
# 33       C/K Line opened and staffed per SOFO.[Bucio]      C10        175
# 34       C/K Line opened and staffed per SOFO.[Bucio]      C10        176
# 35                      T221 R50-2 No ATO doors, 311.      R50          3
# 36                      T221 R50-2 No ATO doors, 311.      R50        163
# 37                      T221 R50-2 No ATO doors, 311.      R50        164
# 38       M/W Line opened and staffed per SOFO[Bucio].      M10          9
# 39       M/W Line opened and staffed per SOFO[Bucio].      M10        169
# 40       M/W Line opened and staffed per SOFO[Bucio].      M10        170
# 41                      T221 R40-2 No ATO doors, 311.      R40         38
# 42                      T221 R40-2 No ATO doors, 311.      R40        213
# 43                      T221 R40-2 No ATO doors, 311.      R40        214
# 44  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30         39
# 45  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30         40
# 46  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30        215
# 47  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30        216
# 48                       T221 R20- No ATO doors, 311.      R20         41
# 49                       T221 R20- No ATO doors, 311.      R20        217
# 50                       T221 R20- No ATO doors, 311.      R20        218
# 51  T221 late arrival to K30-2, forced meet with T...      K30         11
# 52  T221 late arrival to K30-2, forced meet with T...      K30        173
# 53  T221 late arrival to K30-2, forced meet with T...      K30        174
#
#     index_y  X_Percentage  Y_Percentage
# 0        53        18.199        58.303
# 1       239        18.199        58.303
# 2       240        18.199        58.303
# 3        53        18.199        58.303
# 4       239        18.199        58.303
# 5       240        18.199        58.303
# 6        62        66.134        11.020
# 7       257        66.134        11.020
# 8       258        66.134        11.020
# 9        60        44.152        23.910
# 10      253        44.152        23.910
# 11      254        44.152        23.910
# 12       70        38.815        38.337
# 13       71        38.800        38.365
# 14       72        38.807        38.340
# 15      273        38.815        38.337
# 16      274        38.815        38.337
# 17        2        24.080        13.060
# 18      161        24.080        13.060
# 19      162        24.080        13.060
# 20        2        24.080        13.060
# 21      161        24.080        13.060
# 22      162        24.080        13.060
# 23       44        20.000        50.460
# 24      223        20.000        50.460
# 25      224        20.000        50.460
# 26        4        36.250        26.480
# 27      165        36.250        26.480
# 28      166        36.250        26.480
# 29        4        36.250        26.480
# 30      165        36.250        26.480
# 31      166        36.250        26.480
# 32       12        41.697        26.541
# 33      175        41.697        26.541
# 34      176        41.697        26.541
# 35        3        26.500        15.830
# 36      163        26.500        15.830
# 37      164        26.500        15.830
# 38        9        35.195        42.561
# 39      169        35.195        42.561
# 40      170        35.195        42.561
# 41       38        28.896        18.405
# 42      213        28.896        18.405
# 43      214        28.896        18.405
# 44       39        31.330        21.110
# 45       40        31.330        21.110
# 46      215        31.330        21.110
# 47      216        31.330        21.110
# 48       41        33.830        23.800
# 49      217        33.830        23.800
# 50      218        33.830        23.800
# 51       11        38.908        32.784
# 52      173        38.908        32.784
# 53      174        38.908        32.784

# %%
merged_new=merged.drop_duplicates()

# %%
merged_new
# Out:
#     level_0_x  index_x  Time  \
# 0           0        0   622
# 1           0        0   622
# 2           0        0   622
# 3           1        1   640
# 4           1        1   640
# 5           1        1   640
# 6           3        3   658
# 7           3        3   658
# 8           3        3   658
# 9           6        6   732
# 10          6        6   732
# 11          6        6   732
# 12          8        8   745
# 13          8        8   745
# 14          8        8   745
# 15          8        8   745
# 16          8        8   745
# 17          9        9   753
# 18          9        9   753
# 19          9        9   753
# 20         11       11   753
# 21         11       11   753
# 22         11       11   753
# 23         10       10   753
# 24         10       10   753
# 25         10       10   753
# 26         12       12   753
# 27         12       12   753
# 28         12       12   753
# 29         19       19   811
# 30         19       19   811
# 31         19       19   811
# 32         13       13   756
# 33         13       13   756
# 34         13       13   756
# 35         14       14   759
# 36         14       14   759
# 37         14       14   759
# 38         15       15   801
# 39         15       15   801
# 40         15       15   801
# 41         16       16   802
# 42         16       16   802
# 43         16       16   802
# 44         17       17   806
# 45         17       17   806
# 46         17       17   806
# 47         17       17   806
# 48         18       18   809
# 49         18       18   809
# 50         18       18   809
# 51         21       21   816
# 52         21       21   816
# 53         21       21   816
#
#                                                   Log Location  level_0_y  \
# 0   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60         53
# 1   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60        239
# 2   DMZ1 issued Cat B W/O's for MW02 to set on and...      M60        240
# 3   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60         53
# 4   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60        239
# 5   DMZ1 cleared Cat B W/O's for the M1 Track and ...      M60        240
# 6   T950 Inspection train in C80 TM1 dispatching t...      C80         62
# 7   T950 Inspection train in C80 TM1 dispatching t...      C80        257
# 8   T950 Inspection train in C80 TM1 dispatching t...      C80        258
# 9   T918 completed track inspection on the C2 Trac...      C20         60
# 10  T918 completed track inspection on the C2 Trac...      C20        253
# 11  T918 completed track inspection on the C2 Trac...      C20        254
# 12  T918 completed track inspection on the C1 Trac...      K10         70
# 13  T918 completed track inspection on the C1 Trac...      K10         71
# 14  T918 completed track inspection on the C1 Trac...      K10         72
# 15  T918 completed track inspection on the C1 Trac...      K10        273
# 16  T918 completed track inspection on the C1 Trac...      K10        274
# 17                      T221 R60-2 No ATO doors, 311.      R60          2
# 18                      T221 R60-2 No ATO doors, 311.      R60        161
# 19                      T221 R60-2 No ATO doors, 311.      R60        162
# 20                      T221 R60-2 No ATO doors, 311.      R60          2
# 21                      T221 R60-2 No ATO doors, 311.      R60        161
# 22                      T221 R60-2 No ATO doors, 311.      R60        162
# 23  T507 issued road manual into M40-2 and verifie...      M40         44
# 24  T507 issued road manual into M40-2 and verifie...      M40        223
# 25  T507 issued road manual into M40-2 and verifie...      M40        224
# 26  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10          4
# 27  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10        165
# 28  A/L/S & R Line opened and staffed per SOFO.[Bu...      R10        166
# 29                      T221 R10-2 No ATO doors, 311.      R10          4
# 30                      T221 R10-2 No ATO doors, 311.      R10        165
# 31                      T221 R10-2 No ATO doors, 311.      R10        166
# 32       C/K Line opened and staffed per SOFO.[Bucio]      C10         12
# 33       C/K Line opened and staffed per SOFO.[Bucio]      C10        175
# 34       C/K Line opened and staffed per SOFO.[Bucio]      C10        176
# 35                      T221 R50-2 No ATO doors, 311.      R50          3
# 36                      T221 R50-2 No ATO doors, 311.      R50        163
# 37                      T221 R50-2 No ATO doors, 311.      R50        164
# 38       M/W Line opened and staffed per SOFO[Bucio].      M10          9
# 39       M/W Line opened and staffed per SOFO[Bucio].      M10        169
# 40       M/W Line opened and staffed per SOFO[Bucio].      M10        170
# 41                      T221 R40-2 No ATO doors, 311.      R40         38
# 42                      T221 R40-2 No ATO doors, 311.      R40        213
# 43                      T221 R40-2 No ATO doors, 311.      R40        214
# 44  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30         39
# 45  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30         40
# 46  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30        215
# 47  T221 R30-2 No ATO doors, 311. Tango advised Ro...      R30        216
# 48                       T221 R20- No ATO doors, 311.      R20         41
# 49                       T221 R20- No ATO doors, 311.      R20        217
# 50                       T221 R20- No ATO doors, 311.      R20        218
# 51  T221 late arrival to K30-2, forced meet with T...      K30         11
# 52  T221 late arrival to K30-2, forced meet with T...      K30        173
# 53  T221 late arrival to K30-2, forced meet with T...      K30        174
#
#     index_y  X_Percentage  Y_Percentage
# 0        53        18.199        58.303
# 1       239        18.199        58.303
# 2       240        18.199        58.303
# 3        53        18.199        58.303
# 4       239        18.199        58.303
# 5       240        18.199        58.303
# 6        62        66.134        11.020
# 7       257        66.134        11.020
# 8       258        66.134        11.020
# 9        60        44.152        23.910
# 10      253        44.152        23.910
# 11      254        44.152        23.910
# 12       70        38.815        38.337
# 13       71        38.800        38.365
# 14       72        38.807        38.340
# 15      273        38.815        38.337
# 16      274        38.815        38.337
# 17        2        24.080        13.060
# 18      161        24.080        13.060
# 19      162        24.080        13.060
# 20        2        24.080        13.060
# 21      161        24.080        13.060
# 22      162        24.080        13.060
# 23       44        20.000        50.460
# 24      223        20.000        50.460
# 25      224        20.000        50.460
# 26        4        36.250        26.480
# 27      165        36.250        26.480
# 28      166        36.250        26.480
# 29        4        36.250        26.480
# 30      165        36.250        26.480
# 31      166        36.250        26.480
# 32       12        41.697        26.541
# 33      175        41.697        26.541
# 34      176        41.697        26.541
# 35        3        26.500        15.830
# 36      163        26.500        15.830
# 37      164        26.500        15.830
# 38        9        35.195        42.561
# 39      169        35.195        42.561
# 40      170        35.195        42.561
# 41       38        28.896        18.405
# 42      213        28.896        18.405
# 43      214        28.896        18.405
# 44       39        31.330        21.110
# 45       40        31.330        21.110
# 46      215        31.330        21.110
# 47      216        31.330        21.110
# 48       41        33.830        23.800
# 49      217        33.830        23.800
# 50      218        33.830        23.800
# 51       11        38.908        32.784
# 52      173        38.908        32.784
# 53      174        38.908        32.784
